# %%
from flask import Flask, render_template

app = Flask(__name__)

@app.route('/')
def index():
    return render_template('index.html')

if __name__ == '__main__':
    app.run(debug=True)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: on
# Address already in use
# Port 5000 is in use by another program. Either identify and stop that program, or start the server with a different port.
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File /usr/local/python/3.10.4/lib/python3.10/site-packages/werkzeug/serving.py:710, in BaseWSGIServer.__init__(self, host, port, app, handler, passthrough_errors, ssl_context, fd)
#     709 try:
# --> 710     self.server_bind()
#     711     self.server_activate()
#
# File /usr/local/python/3.10.4/lib/python3.10/http/server.py:136, in HTTPServer.server_bind(self)
#     135 """Override server_bind to store the server name."""
# --> 136 socketserver.TCPServer.server_bind(self)
#     137 host, port = self.server_address[:2]
#
# File /usr/local/python/3.10.4/lib/python3.10/socketserver.py:466, in TCPServer.server_bind(self)
# ...
